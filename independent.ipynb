# %%
import pandas as pd

# %%
file_to_load = "/Users/davidlopez/Desktop/DataAnalytics_Homework/ETL_1_FEC_DATA/Resources/indep.csv"

# %%
head_to_load = "/Users/davidlopez/Desktop/DataAnalytics_Homework/ETL_1_FEC_DATA/Resources/pas2_header_file.csv"

# %%
df = pd.read_csv(head_to_load)

# %%
df_column_names = list(df.columns)
df_column_names
# Out:
# ['CMTE_ID',
#  'AMNDT_IND',
#  'RPT_TP',
#  'TRANSACTION_PGI',
#  'IMAGE_NUM',
#  'TRANSACTION_TP',
#  'ENTITY_TP',
#  'NAME',
#  'CITY',
#  'STATE',
#  'ZIP_CODE',
#  'EMPLOYER',
#  'OCCUPATION',
#  'TRANSACTION_DT',
#  'TRANSACTION_AMT',
#  'OTHER_ID',
#  'CAND_ID',
#  'TRAN_ID',
#  'FILE_NUM',
#  'MEMO_CD',
#  'MEMO_TEXT',
#  'SUB_ID']

# %%
df2 = pd.read_csv(file_to_load, header = None)
# Out:
# /Users/davidlopez/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2.head()
# Out:
#           0  1    2      3             4    5    6                       7   \
# 0  C00567180  T  TER      P  2.020000e+17  24K  PAC   TED YOHO FOR CONGRESS
# 1  C00104885  A  TER      P  2.020000e+17  24K  CCM  FRIENDS OF JIM CLYBURN
# 2  C00104885  A  TER      G  2.020000e+17  24K  CCM         TEAM GRAHAM INC
# 3  C00104885  A  TER      P  2.020000e+17  24K  CCM    TIM SCOTT FOR SENATE
# 4  C00688408  T  TER  G2018  2.020000e+17  24E  ORG        JACKSON ADVOCATE
#
#             8   9   ...   12          13    14         15         16  \
# 0  GAINESVILLE  FL  ...  NaN   1082019.0  1880  C00494583  H2FL06109
# 1     COLUMBIA  SC  ...  NaN   1072019.0   470  C00255562  H2SC02042
# 2     COLUMBIA  SC  ...  NaN  12202018.0  3000  C00458828  H4SC03087
# 3   CHARLESTON  SC  ...  NaN  12202018.0  1000  C00540302  H0SC01279
# 4      JACKSON  MS  ...  NaN  12122018.0  1000  S8MS00287  S8MS00287
#
#            17       18   19   20            21
# ...

# %%
df2.columns = df_column_names

# %%
df2.index.name = "Index"

# %%
df2.head()
# Out:
#          CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI     IMAGE_NUM  \
# Index
# 0      C00567180         T    TER               P  2.020000e+17
# 1      C00104885         A    TER               P  2.020000e+17
# 2      C00104885         A    TER               G  2.020000e+17
# 3      C00104885         A    TER               P  2.020000e+17
# 4      C00688408         T    TER           G2018  2.020000e+17
#
#       TRANSACTION_TP ENTITY_TP                    NAME         CITY STATE  \
# Index
# 0                24K       PAC   TED YOHO FOR CONGRESS  GAINESVILLE    FL
# 1                24K       CCM  FRIENDS OF JIM CLYBURN     COLUMBIA    SC
# 2                24K       CCM         TEAM GRAHAM INC     COLUMBIA    SC
# 3                24K       CCM    TIM SCOTT FOR SENATE   CHARLESTON    SC
# 4                24E       ORG        JACKSON ADVOCATE      JACKSON    MS
#
#        ...  OCCUPATION TRANSACTION_DT TRANSACTION_AMT   OTHER_ID    CAND_ID  \
# Index  ...
# ...

# %%
df2
# Out:
# 20000e+17
# 89108  C00104299         N     M9               P  2.020000e+17
# 89109  C00104299         N     M9               P  2.020000e+17
# 89110  C00104299         N     M9               P  2.020000e+17
# 89111  C00104299         N     M9               P  2.020000e+17
# 89112  C00104299         N     M9               P  2.020000e+17
# 89113  C00104299         N     M9               P  2.020000e+17
# 89114  C00104299         N     M9               P  2.020000e+17
# 89115  C00104299         N     M9               P  2.020000e+17
# 89116  C00171843         N     M9               P  2.020000e+17
# 89117  C00171843         N     M9               P  2.020000e+17
# 89118  C00171843         N     M9               P  2.020000e+17
# 89119  C00171843         N     M9               P  2.020000e+17
#
#       TRANSACTION_TP ENTITY_TP  \
# Index
# 0                24K       PAC
# 1                24K       CCM
# 2                24K       CCM
# 3                24K       CCM
# ...

# %%
df2.to_csv('/Users/davidlopez/Desktop/DataAnalytics_Homework/ETL_1_FEC_DATA/Exports/indep_expend_with_header.csv')
