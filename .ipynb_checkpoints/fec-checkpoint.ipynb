# %%
import pandas as pd

# %%
file_to_load = "indep.csv"

# %%
head_to_load = "pas2_header_file.csv"

# %%
df = pd.read_csv(head_to_load)

# %%
df_column_names = list(df.columns)
df_column_names
# Out:
# ['CMTE_ID',
#  'AMNDT_IND',
#  'RPT_TP',
#  'TRANSACTION_PGI',
#  'IMAGE_NUM',
#  'TRANSACTION_TP',
#  'ENTITY_TP',
#  'NAME',
#  'CITY',
#  'STATE',
#  'ZIP_CODE',
#  'EMPLOYER',
#  'OCCUPATION',
#  'TRANSACTION_DT',
#  'TRANSACTION_AMT',
#  'OTHER_ID',
#  'CAND_ID',
#  'TRAN_ID',
#  'FILE_NUM',
#  'MEMO_CD',
#  'MEMO_TEXT',
#  'SUB_ID']

# %%
df2 = pd.read_csv(file_to_load, header = None)

# %%
df2.head()
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI     IMAGE_NUM TRANSACTION_TP  \
# 0  C00567180         T    TER               P  2.020000e+17            24K
# 1  C00104885         A    TER               P  2.020000e+17            24K
# 2  C00104885         A    TER               G  2.020000e+17            24K
# 3  C00104885         A    TER               P  2.020000e+17            24K
# 4  C00688408         T    TER           G2018  2.020000e+17            24E
#
#   ENTITY_TP                    NAME         CITY STATE  ...  OCCUPATION  \
# 0       PAC   TED YOHO FOR CONGRESS  GAINESVILLE    FL  ...         NaN
# 1       CCM  FRIENDS OF JIM CLYBURN     COLUMBIA    SC  ...         NaN
# 2       CCM         TEAM GRAHAM INC     COLUMBIA    SC  ...         NaN
# 3       CCM    TIM SCOTT FOR SENATE   CHARLESTON    SC  ...         NaN
# 4       ORG        JACKSON ADVOCATE      JACKSON    MS  ...         NaN
#
#   TRANSACTION_DT TRANSACTION_AMT   OTHER_ID    CAND_ID     TRAN_ID FILE_NUM  \
# 0      1082019.0            1880  C00494583  H2FL06109   SB23.4447  1303604
# 1      1072019.0             470  C00255562  H2SC02042  SB23.17755  1307636
# 2     12202018.0            3000  C00458828  H4SC03087  SB23.17757  1307636
# 3     12202018.0            1000  C00540302  H0SC01279  SB23.17756  1307636
# 4     12122018.0            1000  S8MS00287  S8MS00287     SE.4233  1310906
#
#   MEMO_CD  MEMO_TEXT        SUB_ID
# 0     NaN        NaN  4.020000e+18
# 1     NaN        NaN  4.020000e+18
# 2     NaN        NaN  4.020000e+18
# 3     NaN        NaN  4.020000e+18
# 4     NaN        NaN  4.020000e+18
#
# [5 rows x 22 columns]

# %%
df2.columns = df_column_names

# %%
df2
# Out:
#          CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI     IMAGE_NUM  \
# 0      C00567180         T    TER               P  2.020000e+17
# 1      C00104885         A    TER               P  2.020000e+17
# 2      C00104885         A    TER               G  2.020000e+17
# 3      C00104885         A    TER               P  2.020000e+17
# 4      C00688408         T    TER           G2018  2.020000e+17
# ...          ...       ...    ...             ...           ...
# 89115  C00104299         N     M9               P  2.020000e+17
# 89116  C00171843         N     M9               P  2.020000e+17
# 89117  C00171843         N     M9               P  2.020000e+17
# 89118  C00171843         N     M9               P  2.020000e+17
# 89119  C00171843         N     M9               P  2.020000e+17
#
#       TRANSACTION_TP ENTITY_TP                        NAME            CITY  \
# 0                24K       PAC       TED YOHO FOR CONGRESS     GAINESVILLE
# 1                24K       CCM      FRIENDS OF JIM CLYBURN        COLUMBIA
# 2                24K       CCM             TEAM GRAHAM INC        COLUMBIA
# 3                24K       CCM        TIM SCOTT FOR SENATE      CHARLESTON
# 4                24E       ORG            JACKSON ADVOCATE         JACKSON
# ...              ...       ...                         ...             ...
# 89115            24K       CCM       WENSTRUP FOR CONGRESS      CINCINNATI
# 89116            24K       CCM        MEADOWS FOR CONGRESS  HENDERSONVILLE
# 89117            24K       CCM         REED COMMITTEE; THE        CRANSTON
# 89118            24K       CCM    KUSTER FOR CONGRESS, INC         CONCORD
# 89119            24K       CCM  DIANA DEGETTE FOR CONGRESS          DENVER
#
#       STATE  ...  OCCUPATION TRANSACTION_DT TRANSACTION_AMT   OTHER_ID  \
# 0        FL  ...         NaN      1082019.0            1880  C00494583
# 1        SC  ...         NaN      1072019.0             470  C00255562
# 2        SC  ...         NaN     12202018.0            3000  C00458828
# 3        SC  ...         NaN     12202018.0            1000  C00540302
# 4        MS  ...         NaN     12122018.0            1000  S8MS00287
# ...     ...  ...         ...            ...             ...        ...
# 89115    OH  ...         NaN      8022019.0            2000  C00497818
# 89116    NC  ...         NaN      8272019.0           -1000  C00503094
# 89117    RI  ...         NaN      8212019.0            1000  C00238907
# 89118    NH  ...         NaN      8212019.0            1000  C00462861
# 89119    CO  ...         NaN      8212019.0            2500  C00311639
#
#          CAND_ID              TRAN_ID FILE_NUM MEMO_CD  \
# 0      H2FL06109            SB23.4447  1303604     NaN
# 1      H2SC02042           SB23.17755  1307636     NaN
# 2      H4SC03087           SB23.17757  1307636     NaN
# 3      H0SC01279           SB23.17756  1307636     NaN
# 4      S8MS00287              SE.4233  1310906     NaN
# ...          ...                  ...      ...     ...
# 89115  H2OH02085  D46E3F9F66FA54354ED  1353190     NaN
# 89116  H2NC11080             10316943  1353417     NaN
# 89117  S6RI00163             10300503  1353417     NaN
# 89118  H0NH02181             10300504  1353417     NaN
# 89119  H6CO01141             10300505  1353417     NaN
#
#                      MEMO_TEXT        SUB_ID
# 0                          NaN  4.020000e+18
# 1                          NaN  4.020000e+18
# 2                          NaN  4.020000e+18
# 3                          NaN  4.020000e+18
# 4                          NaN  4.020000e+18
# ...                        ...           ...
# 89115                      NaN  4.090000e+18
# 89116  VOIDED CK FROM 5/8/2019  4.090000e+18
# 89117             CONTRIBUTION  4.090000e+18
# 89118             CONTRIBUTION  4.090000e+18
# 89119             CONTRIBUTION  4.090000e+18
#
# [89120 rows x 22 columns]
